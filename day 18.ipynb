# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df2 = pd.read_csv('df2')

# %%
df3 = pd.read_csv('df3')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
### Graph functions
1. plot   - simple line plot
2. plot.area - filled version of line plot
3.plot.bar/plot.barh  - bar Graph
4.plot.box- box plot
5. plot.density- Density line(Smooth curved)
6 plot.hexbin- Hexagon Version 
7. plot.hist
8. plot.kde
9 plot.pie
10. plot.scatter
# Out:
#   Input In [9]
#     1. plot
#        ^
# SyntaxError: invalid syntax

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot(); plt.title('Line Plot'); plt.show()
df2.plot.area(); plt.title('Area Plot'); plt.show()
df2.plot.bar(); plt.title('bar Plot'); plt.show()
df2.plot.box(); plt.title('box Plot'); plt.show()
df2.plot.barh(); plt.title('bar horizontal Plot'); plt.show()
df2.plot.density(); plt.title('Density Plot'); plt.show()
df2.plot.kde(); plt.title('KDE Plot'); plt.show()
df2.plot.hist(); plt.title('Histogram Plot'); plt.show()

plt.subplot(4,3,9);df2.plot.scatter(x='a',y='b'); plt.title('Scatter Plot'); plt.show()
plt.subplot(4,3,10);df2.plot.hexbin(x='a',y='b', C='c',gridsize=6); plt.title('Hexbin Plot'); plt.show()

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df4 = pd.DataFrame({'gift':[40,60,80,20],
          'name':['rahul','vinita','vijay','vilakshan']})
df4.head()
# Out:
#    gift       name
# 0    40      rahul
# 1    60     vinita
# 2    80      vijay
# 3    20  vilakshan

# %%
plt.figure(figsize=(5,5))
df4['gift'].plot.pie(autopct='%d%%', labels = df4['name'])
# Out:
# <AxesSubplot:ylabel='gift'>

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Categories
# 1. Categorical Plots(hue can be used)
#    a. countplot
#    b. barplot ( 1 categorical and  1 numerical data)
#    c. violinplot
#    d. swarmplot
# 2. Distribution plots
#    a. distplot
#    b. displot
#    c. jointplot
#    d. pairplot
#    e. kdeplot
#    f. rugplot
#    g. scatterplot
# 3. Matrix plot
#    a. heapmap
#    b. clustermap
#    c. pairplot (same as above one)
# 4. Regression plot
#    a.lnplot
#    b. regplot
# 5. Grid plot
#    a. Pairplot
#    b. Jointplot
#    c. Faceplot

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\OneDrive\Desktop\training\day 18.ipynb Cell 20 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/OneDrive/Desktop/training/day%2018.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> df.info()
#
# NameError: name 'df' is not defined

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.groupby(['sex','time'])['day'].value_counts().sort_index()
# Out:
# sex     time
# Male    Lunch   Thur    30
#                 Fri      3
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     0
#                 Fri      7
#                 Sat     59
#                 Sun     58
# Female  Lunch   Thur    31
#                 Fri      4
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     1
#                 Fri      5
#                 Sat     28
#                 Sun     18
# Name: day, dtype: int64

# %%
sns.countplot(x='day', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time', data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(x='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day', data=tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.barplot(x='day',y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set_style('withgrid')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Dell\OneDrive\Desktop\training\day 18.ipynb Cell 29 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/OneDrive/Desktop/training/day%2018.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> sns.set_style('withgrid')
#
# File c:\Users\Dell\anaconda3\lib\site-packages\seaborn\rcmod.py:337, in set_style(style, rc)
#     309 def set_style(style=None, rc=None):
#     310     """
#     311     Set the parameters that control the general style of the plots.
#     312
#    (...)
#     335
#     336     """
# --> 337     style_object = axes_style(style, rc)
#     338     mpl.rcParams.update(style_object)
#
# File c:\Users\Dell\anaconda3\lib\site-packages\seaborn\rcmod.py:191, in axes_style(style, rc)
#     189 styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
#     190 if style not in styles:
# --> 191     raise ValueError("style must be one of %s" % ", ".join(styles))
#     193 # Define colors here
#     194 dark_gray = ".15"
#
# ValueError: style must be one of white, dark, whitegrid, darkgrid, ticks

# %%
sns.violinplot(x='day',y='total_bill', data=tips,estimator=sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill', data=tips,hue='smoker',
            estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill', data=tips,hue='time'
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips,hue='smoker')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill', data=tips,hue='time')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
